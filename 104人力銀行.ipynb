# %% [markdown]
# # 104

# %%
import requests
from bs4 import BeautifulSoup
import json
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time
url = "https://www.104.com.tw/"
driver=webdriver.Remote("http://localhost:9515",webdriver.DesiredCapabilities.CHROME)
driver.get(url)

## 查詢關鍵字輸入
driver.find_element_by_name('ikeyword').send_keys('machine learning')
driver.find_element_by_class_name('yellow').click()

## 查詢完後網頁之URL
url_new = driver.current_url
# url_new = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&keyword=machine%20learning&order=1"
res=requests.get(url_new,verify=False)
soup = BeautifulSoup(res.text,'lxml')
res = soup.select('.j_cont')

# for i in res:
#     print i.select_one('span').text ## 職缺
#     print i.select_one('.location').text ## 公司地區
#     print i.select_one('.compname_summary').text ## 公司名稱
#     print i.select_one('.requirement').text ## 經驗
#     print url + i.select_one('.jobname_summary').select_one('a')['href'] ##網址
#     print i.select_one('.candidates_summary').select_one('a').text ## 應徵人數

for i in res:
    try:
        job_dict = {}
        job_dict['job'] = i.select_one('span').text.strip() ## 職缺
        job_dict['location']  = i.select_one('.location').text.strip() ## 公司地區
        job_dict['compname']  = i.select_one('.compname_summary').text.strip() ## 公司名稱
        job_dict['exp']  = i.select_one('.requirement').text.strip() ## 經驗
        job_dict['web']  = url + i.select_one('.jobname_summary').select_one('a')['href'].strip() ##網址
        job_dict['count']  = i.select_one('.candidates_summary').select_one('a').text.strip() ## 應徵人數
        for j in job_dict:
            print job_dict[j]     
    except Exception as e:
        print e
    print "==========job==========="
# Out:
# C:\Users\BIG DATA\Anaconda2\lib\site-packages\requests\packages\urllib3\connectionpool.py:838: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/security.html
#   InsecureRequestWarning)
# 6-10人應徵
# https://www.104.com.tw//job/?jobno=46izo&jobsource=n104bank1&hotjob_chr=
# 沛星互動科技股份有限公司
# Machine Learning Scientist
# 台北市信義區
# 3年以上工作經歷，大學學歷，待遇面議
# ==========job===========
# 0-5人應徵
# https://www.104.com.tw//job/?jobno=571ix&jobsource=n104bank1&hotjob_chr=
# LEGOLY, INC.
# Senior Machine Learning NLP Engineer
# 台北市大安區
# 工作經歷不拘，大學學歷，待遇面議
# ==========job===========
# 11-30人應徵
# https://www.104.com.tw//job/?jobno=4iwys&jobsource=n104bank1&hotjob_chr=
# 英屬開曼群島商盾心科技股份有限公司台灣分公司
# Computer Vision / Machine Learning (演算法工程師)
# 台北市信義區
# 工作經歷不拘，大學學歷，待遇面議
# ==========job===========
# 11-30人應徵
# https://www.104.com.tw//job/?jobno=4xru1&jobsource=n104bank1&hotjob_chr=
# ...
