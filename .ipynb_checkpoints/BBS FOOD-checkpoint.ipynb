# %% [markdown]
# ## BBS Scraper

# %%
import requests
from bs4 import BeautifulSoup
import json
res=requests.get('https://www.ptt.cc/bbs/Food/index.html',verify=False)
soup = BeautifulSoup(res.text)
res = soup.select('.r-ent')
# print type(res)
# print res.text
# print res
for i in res:
    article_dict = {}
    article_dict['title'] = i.select_one('.title').text
    article_dict['meta'] = i.select_one('.meta').text
    for k in article_dict:
        print (article_dict[k])
# article_dict
# Out:
# C:\Users\BIG DATA\Anaconda2\lib\site-packages\requests\packages\urllib3\connectionpool.py:838: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/security.html
#   InsecureRequestWarning)
# 12/01
# tonlin
#
#
# [廣宣] 新北中和 三隻貓頭鷹（景安店）
#
#
# 12/16
# Dilbert
#
#
# [公告] Food板 板規 V3.8
#
#
# 11/18
# Yawper
#
#
# 精華區使用方法  【重要！新手必看！】
#
#
#  9/28
# bluefish
#
#
# [公告] 發文請在標題加上地區及提供地址電話。^^
#
#
# 10/01
# Dilbert
#
#
# [公告] 文章被刪除者請洽精華區的資源回收桶

# %% [markdown]
# ### 整理

# %%
import requests
from bs4 import BeautifulSoup
import json
url = "https://www.ptt.cc"
res=requests.get(url + '/bbs/Food/index.html',verify=False)
soup = BeautifulSoup(res.text,'lxml')
res = soup.select('.r-ent')

# ================================================================================================
# <div class="r-ent">
#     <div class="nrec"></div>
#     <div class="mark"></div>
#     <div class="title">
#         <a href="/bbs/Food/M.1479884351.A.003.html">[食記] 萬華。大車輪火車壽司~從青春吃到熟女</a>
#     </div>
#     <div class="meta">
#         <div class="date">11/23</div>
#         <div class="author">phinawu</div>
#     </div>
# </div>
# ================================================================================================

for k in res:
#     print k
    try:
        print k.select_one('span')['href'].strip()
        print k.select_one('a').text.split('[')[1].split(']')[0].strip()
        print k.select_one('a').text.split('[')[1].split(']')[1].strip()
        print url + k.select_one('a')['href'].strip()
        print k.select_one('.date').text.strip()
        print k.select_one('.author').text.strip()
    except Exception as e:
            print k.select_one('a').text.strip()
            print k.select_one('.date').text.strip()
            print k.select_one('.author').text.strip()
            print e
# Out:
# C:\Users\BIG DATA\Anaconda2\lib\site-packages\requests\packages\urllib3\connectionpool.py:838: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/security.html
#   InsecureRequestWarning)
# 食記
# 萬華。大車輪火車壽司~從青春吃到熟女
# https://www.ptt.cc/bbs/Food/M.1479884351.A.003.html
# 11/23
# phinawu
# 食記
# 新竹 Q彈手工烏龍麵－三禾手打麵
# https://www.ptt.cc/bbs/Food/M.1479889700.A.B66.html
# 11/23
# k272821
# 食記
# 台北南京三民越式料理-河內河粉
# https://www.ptt.cc/bbs/Food/M.1479890625.A.318.html
# 11/23
# wlike
# 食記
# 東京銀座 琥珀咖啡 人生必訪的咖啡廳
# https://www.ptt.cc/bbs/Food/M.1479891387.A.EB1.html
# 11/23
# redword1030
# 食記
# 花蓮 順富裕刀削麵
# https://www.ptt.cc/bbs/Food/M.1479892007.A.6CF.html
# 11/23
# wlsherica
# 食記
# 台北 月光假面日式咖哩 天然辣的香氣派
# https://www.ptt.cc/bbs/Food/M.1479892363.A.FA7.html
# 11/23
# lusi
# 食記
# 台北松山台省製燒海鮮羊肉爐 湯頭超鮮甜
# https://www.ptt.cc/bbs/Food/M.1479893242.A.42F.html
# 11/23
# chinchinyo
# 食記
# ...

# %% [markdown]
# ### Json

# %%
import requests
from bs4 import BeautifulSoup
import json
res=requests.get('https://www.ptt.cc/bbs/Food/index.html',verify=False)
soup = BeautifulSoup(res.text,'lxml')

res = soup.select('.r-ent')
#res[0].text

for i in res:
    article_dict = {}
    article_dict['title'] = i.select_one('.title').text
    article_dict['meta'] = i.select_one('.meta').text
    for k in article_dict:
        print(article_dict[k])
    articles.append(article_dict)
articles = []

## 生成json檔案    
resjson = json.dumps(articles, ensure_ascii=False)
print resjson
with open('resjson.json', 'w') as f:
    f.write(resjson.encode('utf-8'))
# Out:
# C:\Users\BIG DATA\Anaconda2\lib\site-packages\requests\packages\urllib3\connectionpool.py:838: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/security.html
#   InsecureRequestWarning)
# 11/23
# phinawu
#
#
# [食記] 萬華。大車輪火車壽司~從青春吃到熟女
#
#
# 11/23
# k272821
#
#
# [食記] 新竹 Q彈手工烏龍麵－三禾手打麵
#
#
# 11/23
# wlike
#
#
# [食記] 台北南京三民越式料理-河內河粉
#
#
# 11/23
# redword1030
#
#
# [食記] 東京銀座 琥珀咖啡 人生必訪的咖啡廳
#
#
# 11/23
# wlsherica
#
#
# [食記] 花蓮 順富裕刀削麵
#
#
# 11/23
# lusi
#
#
# [食記] 台北 月光假面日式咖哩 天然辣的香氣派
#
#
# 11/23
# chinchinyo
#
#
# [食記] 台北松山台省製燒海鮮羊肉爐 湯頭超鮮甜
#
#
# 11/23
# taliya
#
#
# [食記] 印尼峇里島 豬不可貌相淘氣諾莉烤豬肋排
#
#
# 11/23
# yoyoben
#
#
# [食記] 高雄 替人著想小餐館-小港平價無菜單料理
#
#
# 11/23
# LeeGiKwang
#
#
# [食記] 胡志明-The KAfe，美好的班尼迪克蛋早晨
#
#
# 11/23
# vn513868
#
#
# [食記] 台北 初魚料亭 無菜單料理 壽司生魚片
#
#
# 11/23
# windsora
#
#
# Fw: [食記] 東京千代田 炸牛排壹貳參 秋葉原知名美食
#
#
# 11/23
# diet83
#
#
# [食記] 台北OOH CHA CHA 自然食 天然的蔬食漢堡 甜點
#
#
# ...
